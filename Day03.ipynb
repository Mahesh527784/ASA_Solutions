# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh527784/ASA_Solutions/blob/main/Day03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/souviksamanta1053/ipl-2025-mega-auction-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: servicenowsmtp
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/souviksamanta1053/ipl-2025-mega-auction-dataset
# ...
# 100%|██████████| 6.92k/6.92k [00:00<00:00, 6.06MB/s]

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/ipl-2025-mega-auction-dataset/ipl_2025_auction_players.csv")
(data.head())
# Out:
#             Players Team  Type Base   Sold
# 0       Virat Kohli  RCB   BAT    -  21.00
# 1     Rajat Patidar  RCB   BAT    -  11.00
# 2        Yash Dayal  RCB  BOWL    -   5.00
# 3    Jasprit Bumrah   MI  BOWL    -  18.00
# 4  Suryakumar Yadav   MI   BAT    -  16.35

# %%
pd.DataFrame(data)

# pd.Series(data.)
# Out:
#                  Players Team  Type  Base    Sold
# 0            Virat Kohli  RCB   BAT     -   21.00
# 1          Rajat Patidar  RCB   BAT     -   11.00
# 2             Yash Dayal  RCB  BOWL     -    5.00
# 3         Jasprit Bumrah   MI  BOWL     -   18.00
# 4       Suryakumar Yadav   MI   BAT     -   16.35
# ..                   ...  ...   ...   ...     ...
# 618          Vijay Yadav    -    AR  0.30     TBA
# 619         Jofra Archer   RR  BOWL  2.00   12.50
# 620  Saurabh Netravalkar    -  BOWL  0.30     TBA
# 621        Hardik Tamore    -    WK  0.30     TBA
# 622       Daryl Mitchell    -    AR  2.00  Unsold
#
# [623 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['Players', 'Team', 'Type', 'Base', 'Sold'], dtype='object')

# %%
pd.Series(data.head().get("Players"))
# Out:
# 0         Virat Kohli
# 1       Rajat Patidar
# 2          Yash Dayal
# 3      Jasprit Bumrah
# 4    Suryakumar Yadav
# Name: Players, dtype: object

# %%
data.sort_values(by=["Sold",'Base'],ascending=True)
# Out:
#              Players Team  Type  Base  Sold
# 96     Atharva Taide  SRH   BAT  0.30   0.3
# 105   Nishant Sindhu   GT    AR  0.30   0.3
# 107      Aryan Juyal  LSG   BAT  0.30   0.3
# 110       Anuj Rawat   GT   BAT  0.30   0.3
# 111  Luvnith Sisodia  KKR   BAT  0.30   0.3
# ..               ...  ...   ...   ...   ...
# 413       Adam Milne    -  BOWL  2.00   NaN
# 449     Jason Holder    -    AR  2.00   NaN
# 525     Chris Jordan    -  BOWL  2.00   NaN
# 527      Tymal Mills    -  BOWL  2.00   NaN
# 622   Daryl Mitchell    -    AR  2.00   NaN
#
# [623 rows x 5 columns]

# %%
sold_dtypes = data['Sold'].dtypes
is_int = pd.api.types.is_integer_dtype(sold_dtypes)
# Instead of filtering the DataFrame, change the dtype of the 'Sold' column to numeric
# errors='coerce' will replace non-numeric values with NaN
data['Sold'] = pd.to_numeric(data['Sold'], errors='coerce')
# Now you can filter for integer values
data2 = data[data['Sold'].apply(lambda x: isinstance(x, int))]
data2.sort_values(by=["Sold", 'Base'], ascending=True)
# Out:
# Empty DataFrame
# Columns: [Players, Team, Type, Base, Sold]
# Index: []

# %%
data.head()
# Out:
#             Players Team  Type Base   Sold
# 0       Virat Kohli  RCB   BAT    -  21.00
# 1     Rajat Patidar  RCB   BAT    -  11.00
# 2        Yash Dayal  RCB  BOWL    -   5.00
# 3    Jasprit Bumrah   MI  BOWL    -  18.00
# 4  Suryakumar Yadav   MI   BAT    -  16.35

# %%
data.tail()
# Out:
#                  Players Team  Type  Base  Sold
# 618          Vijay Yadav    -    AR  0.30   NaN
# 619         Jofra Archer   RR  BOWL  2.00  12.5
# 620  Saurabh Netravalkar    -  BOWL  0.30   NaN
# 621        Hardik Tamore    -    WK  0.30   NaN
# 622       Daryl Mitchell    -    AR  2.00   NaN

# %%
# prompt: write a code for getting last 20 records

import pandas as pd

# Assuming 'data' is your DataFrame (as defined in the previous code)
last_20_records = data.tail(20)
last_20_records
# Out:
#                  Players Team  Type  Base  Sold
# 603           Arjun Azad    -    AR  0.30   NaN
# 604      Abhay Choudhary    -    AR  0.30   NaN
# 605       Gaurav Gambhir    -    AR  0.30   NaN
# 606      Shubham Garhwal    -    AR  0.30   NaN
# 607      Tejasvi Jaiswal    -    AR  0.30   NaN
# 608         Sairaj Patil    -    AR  0.30   NaN
# 609        Madhav Tiwari   DC    AR  0.30   0.4
# 610       Kamal Tripathi    -    AR  0.30   NaN
# 611     Prashant Chauhan    -    AR  0.30   NaN
# 612           Yash Dabas    -    AR  0.30   NaN
# 613        Dhruv Kaushik    -    AR  0.30   NaN
# 614     Khrievitso Kense    -    AR  0.30   NaN
# 615         Akash Parkar    -    AR  0.30   NaN
# 616       Vignesh Puthur   MI    AR  0.30   0.3
# 617      Tripuresh Singh    -    AR  0.30   NaN
# 618          Vijay Yadav    -    AR  0.30   NaN
# 619         Jofra Archer   RR  BOWL  2.00  12.5
# 620  Saurabh Netravalkar    -  BOWL  0.30   NaN
# 621        Hardik Tamore    -    WK  0.30   NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Players  623 non-null    object
#  1   Team     623 non-null    object
#  2   Type     623 non-null    object
#  3   Base     623 non-null    object
#  4   Sold     227 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 24.5+ KB
