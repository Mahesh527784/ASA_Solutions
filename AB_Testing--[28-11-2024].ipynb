# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh527784/ASA_Solutions/blob/main/A_B_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: by taking ipl auction base price and  sold price as data set generate the AB testing

import pandas as pd
from scipy.stats import ttest_ind

# Sample IPL auction data (replace with your actual data)
data = {
    'Player': ['Player1', 'Player2', 'Player3', 'Player4', 'Player5', 'Player6', 'Player7', 'Player8', 'Player9', 'Player10'],
    'Base_Price': [100, 50, 200, 75, 150, 120, 80, 60, 250, 90],  # in lakhs
    'Sold_Price': [120, 70, 250, 100, 180, 150, 90, 75, 300, 110],  # in lakhs
    'Group': ['A', 'A', 'B', 'A', 'B', 'B', 'A', 'A', 'B', 'A']  # Example grouping - replace with your criteria
}

df = pd.DataFrame(data)


# Perform A/B Testing (t-test)
group_a = df[df['Group'] == 'A']['Sold_Price']
group_b = df[df['Group'] == 'B']['Sold_Price']

t_statistic, p_value = ttest_ind(group_a, group_b)

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

alpha = 0.05  # Significance level

if p_value < alpha:
    print("There is a statistically significant difference in sold prices between the two groups.")
else:
    print("There is no statistically significant difference in sold prices between the two groups.")

#Example to calculate the difference in means
mean_diff = group_a.mean() - group_b.mean()
print("Difference in means between Group A and Group B", mean_diff)
# Out:
# T-statistic: -4.397527194690369
# P-value: 0.002294328003025097
# There is a statistically significant difference in sold prices between the two groups.
# Difference in means between Group A and Group B -125.83333333333333

# %%
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/sergylog/ab-test-data")
# Out:
# ...
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: servicenowsmtp
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/sergylog/ab-test-data
# ...
# 100%|██████████| 28.3k/28.3k [00:00<00:00, 10.2MB/s]

# %%
import pandas as pd
data = pd.read_csv('/content/ab-test-data/AB_Test_Results.csv')
data.head()
# Out:
#    USER_ID VARIANT_NAME  REVENUE
# 0      737      variant      0.0
# 1     2423      control      0.0
# 2     9411      control      0.0
# 3     7311      control      0.0
# 4     6174      variant      0.0

# %%
# prompt: Using dataframe data: do the ab testing for it

import pandas as pd
from scipy import stats

# Calculate the average revenue for each variant
control_revenue = data[data['VARIANT_NAME'] == 'control']['REVENUE']
variant_revenue = data[data['VARIANT_NAME'] == 'variant']['REVENUE']

control_mean = control_revenue.mean()
variant_mean = variant_revenue.mean()


# Perform an independent samples t-test
t_statistic, p_value = stats.ttest_ind(control_revenue, variant_revenue)

# Print the results
print("Control Mean Revenue:", control_mean)
print("Variant Mean Revenue:", variant_mean)
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("There is a statistically significant difference in revenue between the control and variant groups.")
else:
    print("There is no statistically significant difference in revenue between the control and variant groups.")
# Out:
# Control Mean Revenue: 0.12901284109149277
# Variant Mean Revenue: 0.07006977671451356
# T-statistic: 1.2711634519010084
# P-value: 0.20370007853373565
# There is no statistically significant difference in revenue between the control and variant groups.

# %%
# prompt: generate the high level graph using seaborn

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' DataFrame from the previous code is available

# Create a boxplot
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
sns.boxplot(x='VARIANT_NAME', y='REVENUE', data=data)
plt.title('Revenue Distribution by Variant')
plt.xlabel('Variant')
plt.ylabel('Revenue')
plt.show()

# Create a violinplot
plt.figure(figsize=(8, 6))
sns.violinplot(x='VARIANT_NAME', y='REVENUE', data=data)
plt.title('Revenue Distribution by Variant (Violin Plot)')
plt.xlabel('Variant')
plt.ylabel('Revenue')
plt.show()

# Create a barplot of the mean revenue
plt.figure(figsize=(6,4))
sns.barplot(x='VARIANT_NAME', y='REVENUE', data=data, estimator=sum)
plt.title('Total Revenue by Variant')
plt.xlabel('Variant')
plt.ylabel('Total Revenue')
plt.show()

# %%
# prompt: and also draw the voilen graph

import pandas as pd
from scipy.stats import ttest_ind
import opendatasets as od
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt


# Sample IPL auction data (replace with your actual data)
data = {
    'Player': ['Player1', 'Player2', 'Player3', 'Player4', 'Player5', 'Player6', 'Player7', 'Player8', 'Player9', 'Player10'],
    'Base_Price': [100, 50, 200, 75, 150, 120, 80, 60, 250, 90],  # in lakhs
    'Sold_Price': [120, 70, 250, 100, 180, 150, 90, 75, 300, 110],  # in lakhs
    'Group': ['A', 'A', 'B', 'A', 'B', 'B', 'A', 'A', 'B', 'A']  # Example grouping - replace with your criteria
}

df = pd.DataFrame(data)


# Perform A/B Testing (t-test)
group_a = df[df['Group'] == 'A']['Sold_Price']
group_b = df[df['Group'] == 'B']['Sold_Price']

t_statistic, p_value = ttest_ind(group_a, group_b)

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

alpha = 0.05  # Significance level

if p_value < alpha:
    print("There is a statistically significant difference in sold prices between the two groups.")
else:
    print("There is no statistically significant difference in sold prices between the two groups.")

#Example to calculate the difference in means
mean_diff = group_a.mean() - group_b.mean()
print("Difference in means between Group A and Group B", mean_diff)
# !pip install opendatasets
od.download("https://www.kaggle.com/datasets/sergylog/ab-test-data")
data = pd.read_csv('/content/ab-test-data/AB_Test_Results.csv')
data.head()


# Calculate the average revenue for each variant
control_revenue = data[data['VARIANT_NAME'] == 'control']['REVENUE']
variant_revenue = data[data['VARIANT_NAME'] == 'variant']['REVENUE']

control_mean = control_revenue.mean()
variant_mean = variant_revenue.mean()


# Perform an independent samples t-test
t_statistic, p_value = stats.ttest_ind(control_revenue, variant_revenue)

# Print the results
print("Control Mean Revenue:", control_mean)
print("Variant Mean Revenue:", variant_mean)
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("There is a statistically significant difference in revenue between the control and variant groups.")
else:
    print("There is no statistically significant difference in revenue between the control and variant groups.")



# Assuming 'data' DataFrame from the previous code is available

# Create a violinplot
plt.figure(figsize=(8, 6))
sns.violinplot(x='VARIANT_NAME', y='REVENUE', data=data)
plt.title('Revenue Distribution by Variant (Violin Plot)')
plt.xlabel('Variant')
plt.ylabel('Revenue')
plt.show()
# Out:
# T-statistic: -4.397527194690369
# P-value: 0.002294328003025097
# There is a statistically significant difference in sold prices between the two groups.
# Difference in means between Group A and Group B -125.83333333333333
# ...
# Skipping, found downloaded files in "./ab-test-data" (use force=True to force download)
# Control Mean Revenue: 0.12901284109149277
# Variant Mean Revenue: 0.07006977671451356
# T-statistic: 1.2711634519010084
# P-value: 0.20370007853373565
# There is no statistically significant difference in revenue between the control and variant groups.
